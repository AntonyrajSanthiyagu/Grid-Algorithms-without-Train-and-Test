# %%
#importing the Libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset['charges']

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.model_selection import GridSearchCV
#from sklearn.tree import DecisionTreeRegressor
param_grid = {'criterion':['squared_error', 'poisson', 'absolute_error', 'friedman_mse'],'max_features': [None,'sqrt','log2'],
'n_estimators':[10,100]}
grid = GridSearchCV(RandomForestRegressor(),param_grid,refit = True,cv=5,verbose= 3,n_jobs=-1)
# fitting the model for grid search
grid.fit(indep,dep)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# GridSearchCV(cv=5, estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'poisson',
#                                        'absolute_error', 'friedman_mse'],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
Y_pred=grid.predict(indep)

# %%
#print best parameter after tuning
#print(grid.best_params_)
re=grid.cv_results_
from sklearn.metrics import r2_score
r_score=r2_score(dep,Y_pred)
print("The R_score value for best parameter {}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for best parameter {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'n_estimators': 100}: 0.9759677870070362

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.248915      0.123185         0.009573        0.014630
# 1        1.333682      0.071773         0.038240        0.010406
# 2        0.100941      0.008422         0.005130        0.006529
# 3        1.078545      0.171162         0.056024        0.024513
# 4        0.123649      0.016446         0.012427        0.015910
# 5        1.101316      0.179693         0.033381        0.002872
# 6        0.133009      0.003464         0.010033        0.005516
# 7        1.312983      0.016965         0.039452        0.008747
# 8        0.110175      0.005702         0.010106        0.006390
# 9        0.985638      0.019880         0.034471        0.008132
# 10       0.106377      0.004778         0.008075        0.004038
# 11       0.939702      0.021763         0.035558        0.004571
# 12       0.574548      0.091413         0.009804        0.005321
# 13       5.394373      0.234355         0.029212        0.006213
# 14       0.317884      0.033422         0.005140        0.006537
# 15       3.368216      0.351552         0.032242        0.007943
# 16       0.319498      0.024873         0.009188        0.005133
# 17       3.710658      0.161834         0.039402        0.003124
# 18       0.147072      0.020059         0.011081        0.015569
# 19       1.356450      0.055751         0.045679        0.013564
# 20       0.102950      0.005481         0.008066        0.004033
# 21       0.952649      0.026801         0.032342        0.004097
# 22       0.099257      0.007657         0.012126        0.004044
# 23       0.879682      0.090908         0.034582        0.004797
#
#    param_criterion param_max_features param_n_estimators  \
# 0    squared_error               None                 10
# 1    squared_error               None                100
# 2    squared_error               sqrt                 10
# 3    squared_error               sqrt                100
# 4    squared_error               log2                 10
# 5    squared_error               log2                100
# 6          poisson               None                 10
# 7          poisson               None                100
# 8          poisson               sqrt                 10
# 9          poisson               sqrt                100
# 10         poisson               log2                 10
# 11         poisson               log2                100
# 12  absolute_error               None                 10
# 13  absolute_error               None                100
# 14  absolute_error               sqrt                 10
# 15  absolute_error               sqrt                100
# 16  absolute_error               log2                 10
# 17  absolute_error               log2                100
# 18    friedman_mse               None                 10
# 19    friedman_mse               None                100
# 20    friedman_mse               sqrt                 10
# 21    friedman_mse               sqrt                100
# 22    friedman_mse               log2                 10
# 23    friedman_mse               log2                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.821322
# 1   {'criterion': 'squared_error', 'max_features':...           0.847617
# 2   {'criterion': 'squared_error', 'max_features':...           0.841414
# 3   {'criterion': 'squared_error', 'max_features':...           0.856185
# 4   {'criterion': 'squared_error', 'max_features':...           0.831954
# 5   {'criterion': 'squared_error', 'max_features':...           0.855937
# 6   {'criterion': 'poisson', 'max_features': None,...           0.827824
# 7   {'criterion': 'poisson', 'max_features': None,...           0.849192
# 8   {'criterion': 'poisson', 'max_features': 'sqrt...           0.846386
# 9   {'criterion': 'poisson', 'max_features': 'sqrt...           0.857268
# 10  {'criterion': 'poisson', 'max_features': 'log2...           0.842964
# 11  {'criterion': 'poisson', 'max_features': 'log2...           0.858314
# 12  {'criterion': 'absolute_error', 'max_features'...           0.829091
# 13  {'criterion': 'absolute_error', 'max_features'...           0.839321
# 14  {'criterion': 'absolute_error', 'max_features'...           0.848898
# 15  {'criterion': 'absolute_error', 'max_features'...           0.858630
# 16  {'criterion': 'absolute_error', 'max_features'...           0.857116
# 17  {'criterion': 'absolute_error', 'max_features'...           0.856651
# 18  {'criterion': 'friedman_mse', 'max_features': ...           0.823934
# 19  {'criterion': 'friedman_mse', 'max_features': ...           0.845475
# 20  {'criterion': 'friedman_mse', 'max_features': ...           0.849622
# 21  {'criterion': 'friedman_mse', 'max_features': ...           0.861613
# 22  {'criterion': 'friedman_mse', 'max_features': ...           0.845109
# 23  {'criterion': 'friedman_mse', 'max_features': ...           0.857262
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.768198           0.829526           0.809079
# 1            0.775907           0.854907           0.817140
# 2            0.755947           0.845344           0.809373
# 3            0.774436           0.860099           0.827713
# 4            0.766777           0.838855           0.825842
# 5            0.780371           0.857969           0.824502
# 6            0.753521           0.845580           0.806111
# 7            0.771048           0.856015           0.815851
# 8            0.759062           0.849402           0.816162
# 9            0.773292           0.861539           0.829335
# 10           0.754252           0.854385           0.806192
# 11           0.777653           0.861197           0.827591
# 12           0.764781           0.845536           0.809328
# 13           0.768289           0.850082           0.821481
# 14           0.768671           0.837783           0.814947
# 15           0.780323           0.858750           0.826580
# 16           0.762591           0.829273           0.826180
# 17           0.778426           0.852081           0.828501
# 18           0.756560           0.838726           0.806565
# 19           0.771880           0.860346           0.818753
# 20           0.760036           0.844891           0.812190
# 21           0.778572           0.861813           0.828729
# 22           0.749615           0.849412           0.813314
# 23           0.778852           0.861714           0.831160
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.816540         0.808933        0.021423               24
# 1            0.830276         0.825169        0.027949               11
# 2            0.818580         0.814132        0.032083               21
# 3            0.843151         0.832317        0.031082                5
# 4            0.831748         0.819035        0.026452               16
# 5            0.840596         0.831875        0.028436                7
# 6            0.830218         0.812651        0.032132               23
# 7            0.839652         0.826352        0.030813               10
# 8            0.831690         0.820541        0.032936               15
# 9            0.839469         0.832181        0.031687                6
# 10           0.825513         0.816661        0.035207               18
# 11           0.838965         0.832744        0.030211                4
# 12           0.823895         0.814526        0.027434               20
# 13           0.837403         0.823315        0.028991               12
# 14           0.841755         0.822411        0.029174               13
# 15           0.846469         0.834150        0.029363                2
# 16           0.832121         0.821456        0.031413               14
# 17           0.837965         0.830725        0.028003                8
# 18           0.842178         0.813593        0.031170               22
# 19           0.836458         0.826582        0.030490                9
# 20           0.816561         0.816660        0.031968               19
# 21           0.842710         0.834687        0.030691                1
# 22           0.827369         0.816964        0.036062               17
# 23           0.841334         0.834065        0.029706                3

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 59
# BMI: 95
# Children: 3
# Sex Male 0 or 1: 0
# Smoker Yes 0 or 1: 1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
#change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[49540.377952]
# C:\Anaconda 3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
