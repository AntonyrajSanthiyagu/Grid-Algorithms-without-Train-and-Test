# %%
#importing the Libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset['charges']

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid = {'criterion': ['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],
    'splitter': ['best', 'random'],
    'max_features': [None, 'sqrt', 'log2']}
   
grid = GridSearchCV(DecisionTreeRegressor(),param_grid,refit = True,cv=5,verbose = 3,n_jobs=-1)
# fitting the model for grid search
grid.fit(indep, dep)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
Y_pred=grid.predict(indep)

# %%
#print best parameter after tuning
#print(grid.best_params_)
re=grid.cv_results_
from sklearn.metrics import r2_score
r_score=r2_score(dep,Y_pred)
print("The R_score value for best parameter {}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for best parameter {'criterion': 'poisson', 'max_features': None, 'splitter': 'best'}: 0.998667156135576

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.408387      0.187303         0.060519        0.030276
# 1        0.056914      0.024493         0.009004        0.004660
# 2        0.023259      0.002694         0.010879        0.006254
# 3        0.018090      0.005742         0.004811        0.005160
# 4        0.096832      0.037054         0.013723        0.001965
# 5        0.013706      0.001831         0.008358        0.004990
# 6        0.022433      0.005250         0.006777        0.002224
# 7        0.016915      0.002614         0.010842        0.002332
# 8        0.016955      0.002311         0.006524        0.001594
# 9        0.014545      0.002534         0.007390        0.002996
# 10       0.017882      0.002306         0.008981        0.001529
# 11       0.015503      0.003593         0.004500        0.002685
# 12       0.124118      0.020330         0.006765        0.002980
# 13       0.085190      0.013618         0.006557        0.002152
# 14       0.061946      0.002007         0.005088        0.000969
# 15       0.070622      0.017066         0.011857        0.006459
# 16       0.080324      0.017980         0.005961        0.001266
# 17       0.069201      0.014565         0.008686        0.005317
# 18       0.029352      0.010096         0.006396        0.001854
# 19       0.019704      0.007891         0.006926        0.001038
# 20       0.018535      0.001363         0.006926        0.000703
# 21       0.013263      0.002024         0.008279        0.003807
# 22       0.021447      0.007018         0.008689        0.003417
# 23       0.023835      0.006679         0.007337        0.004753
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               None           best
# 1    squared_error               None         random
# 2    squared_error               sqrt           best
# 3    squared_error               sqrt         random
# 4    squared_error               log2           best
# 5    squared_error               log2         random
# 6     friedman_mse               None           best
# 7     friedman_mse               None         random
# 8     friedman_mse               sqrt           best
# 9     friedman_mse               sqrt         random
# 10    friedman_mse               log2           best
# 11    friedman_mse               log2         random
# 12  absolute_error               None           best
# 13  absolute_error               None         random
# 14  absolute_error               sqrt           best
# 15  absolute_error               sqrt         random
# 16  absolute_error               log2           best
# 17  absolute_error               log2         random
# 18         poisson               None           best
# 19         poisson               None         random
# 20         poisson               sqrt           best
# 21         poisson               sqrt         random
# 22         poisson               log2           best
# 23         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.718874
# 1   {'criterion': 'squared_error', 'max_features':...           0.693570
# 2   {'criterion': 'squared_error', 'max_features':...           0.664332
# 3   {'criterion': 'squared_error', 'max_features':...           0.703141
# 4   {'criterion': 'squared_error', 'max_features':...           0.629659
# 5   {'criterion': 'squared_error', 'max_features':...           0.715478
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.716560
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.651358
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.764339
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.553992
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.769384
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.664017
# 12  {'criterion': 'absolute_error', 'max_features'...           0.721039
# 13  {'criterion': 'absolute_error', 'max_features'...           0.752830
# 14  {'criterion': 'absolute_error', 'max_features'...           0.660337
# 15  {'criterion': 'absolute_error', 'max_features'...           0.709699
# 16  {'criterion': 'absolute_error', 'max_features'...           0.720036
# 17  {'criterion': 'absolute_error', 'max_features'...           0.603969
# 18  {'criterion': 'poisson', 'max_features': None,...           0.743609
# 19  {'criterion': 'poisson', 'max_features': None,...           0.670720
# 20  {'criterion': 'poisson', 'max_features': 'sqrt...           0.560124
# 21  {'criterion': 'poisson', 'max_features': 'sqrt...           0.712250
# 22  {'criterion': 'poisson', 'max_features': 'log2...           0.713113
# 23  {'criterion': 'poisson', 'max_features': 'log2...           0.735527
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.660036           0.731259           0.736859
# 1            0.614620           0.723451           0.677322
# 2            0.616792           0.509462           0.678195
# 3            0.550444           0.457276           0.685733
# 4            0.556476           0.723276           0.721506
# 5            0.555625           0.721312           0.588557
# 6            0.657668           0.730305           0.701976
# 7            0.616261           0.719263           0.713941
# 8            0.559369           0.669524           0.495879
# 9            0.555784           0.627330           0.594553
# 10           0.642091           0.738775           0.717566
# 11           0.536725           0.657295           0.678856
# 12           0.591388           0.726071           0.735139
# 13           0.593306           0.747596           0.719676
# 14           0.634074           0.686556           0.616686
# 15           0.597940           0.719038           0.703830
# 16           0.600125           0.689680           0.696985
# 17           0.569848           0.741525           0.751563
# 18           0.659589           0.755516           0.713109
# 19           0.581571           0.714421           0.711932
# 20           0.697636           0.570556           0.700069
# 21           0.547429           0.657837           0.720850
# 22           0.594429           0.661186           0.634231
# 23           0.641810           0.565631           0.641776
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.678238         0.705053        0.030447                3
# 1            0.734556         0.688704        0.042312                8
# 2            0.718361         0.637428        0.071746               21
# 3            0.721726         0.623664        0.102792               22
# 4            0.703743         0.666932        0.064958               11
# 5            0.699460         0.656087        0.069736               16
# 6            0.688630         0.699028        0.024952                5
# 7            0.661002         0.672365        0.039105               10
# 8            0.589188         0.615660        0.092977               23
# 9            0.723690         0.611070        0.062506               24
# 10           0.617644         0.697092        0.057827                6
# 11           0.700333         0.647445        0.057296               18
# 12           0.741232         0.702974        0.056231                4
# 13           0.753782         0.713438        0.061346                2
# 14           0.596776         0.638886        0.031691               20
# 15           0.594946         0.665091        0.056268               12
# 16           0.741619         0.689689        0.048358                7
# 17           0.629556         0.659292        0.073785               15
# 18           0.714350         0.717235        0.033195                1
# 19           0.718846         0.679498        0.051936                9
# 20           0.782343         0.662146        0.084785               13
# 21           0.640346         0.655742        0.062298               17
# 22           0.703858         0.661363        0.044046               14
# 23           0.632314         0.643412        0.054154               19

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 65
# BMI: 79
# Children: 3
# Sex Male 0 or 1: 1
# Smoker Yes 0 or 1: 0

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
#change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[15555.18875]
# C:\Anaconda 3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %%
import pickle
filename="finalized_model_DRGridsearchCV.sav"

# %%
pickle.dump(grid,open(filename,'wb'))
