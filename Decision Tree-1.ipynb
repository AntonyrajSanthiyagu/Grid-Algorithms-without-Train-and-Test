# %%
#importing the Libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset['charges']

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid = {'criterion': ['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],
    'splitter': ['best', 'random'],
    'max_features': [None, 'sqrt', 'log2']}
   
grid = GridSearchCV(DecisionTreeRegressor(),param_grid,refit = True,cv=5,verbose = 3,n_jobs=-1)
# fitting the model for grid search
grid.fit(indep, dep)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
Y_pred=grid.predict(indep)

# %%
#print best parameter after tuning
#print(grid.best_params_)
re=grid.cv_results_
from sklearn.metrics import r2_score
r_score=r2_score(dep,Y_pred)
print("The R_score value for best parameter {}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for best parameter {'criterion': 'poisson', 'max_features': None, 'splitter': 'best'}: 0.998667156135576

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.274518      0.118435         0.007796        0.001832
# 1        0.015991      0.002529         0.012706        0.007639
# 2        0.021508      0.008425         0.009528        0.004232
# 3        0.026510      0.006811         0.011694        0.005086
# 4        0.045125      0.017487         0.015114        0.005782
# 5        0.022593      0.004713         0.011401        0.004353
# 6        0.037101      0.005416         0.009195        0.002560
# 7        0.025591      0.001773         0.011793        0.003543
# 8        0.026397      0.004210         0.011406        0.002248
# 9        0.014300      0.003083         0.008003        0.001578
# 10       0.020127      0.003373         0.008794        0.002426
# 11       0.018018      0.006839         0.008305        0.002679
# 12       0.132939      0.018720         0.005415        0.000813
# 13       0.111601      0.013438         0.006499        0.001341
# 14       0.073568      0.010739         0.009194        0.002637
# 15       0.056608      0.004575         0.008396        0.002649
# 16       0.070497      0.004348         0.004598        0.000490
# 17       0.048306      0.009833         0.006402        0.002068
# 18       0.083295      0.066748         0.010194        0.005977
# 19       0.035444      0.016266         0.009794        0.004351
# 20       0.031349      0.012820         0.006100        0.000797
# 21       0.026703      0.008618         0.010493        0.006606
# 22       0.028704      0.006753         0.007506        0.001585
# 23       0.024894      0.005016         0.009595        0.001356
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               None           best
# 1    squared_error               None         random
# 2    squared_error               sqrt           best
# 3    squared_error               sqrt         random
# 4    squared_error               log2           best
# 5    squared_error               log2         random
# 6     friedman_mse               None           best
# 7     friedman_mse               None         random
# 8     friedman_mse               sqrt           best
# 9     friedman_mse               sqrt         random
# 10    friedman_mse               log2           best
# 11    friedman_mse               log2         random
# 12  absolute_error               None           best
# 13  absolute_error               None         random
# 14  absolute_error               sqrt           best
# 15  absolute_error               sqrt         random
# 16  absolute_error               log2           best
# 17  absolute_error               log2         random
# 18         poisson               None           best
# 19         poisson               None         random
# 20         poisson               sqrt           best
# 21         poisson               sqrt         random
# 22         poisson               log2           best
# 23         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.725710
# 1   {'criterion': 'squared_error', 'max_features':...           0.751730
# 2   {'criterion': 'squared_error', 'max_features':...           0.717491
# 3   {'criterion': 'squared_error', 'max_features':...           0.704409
# 4   {'criterion': 'squared_error', 'max_features':...           0.707062
# 5   {'criterion': 'squared_error', 'max_features':...           0.667295
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.720904
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.651384
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.674920
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.756784
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.736226
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.717124
# 12  {'criterion': 'absolute_error', 'max_features'...           0.726757
# 13  {'criterion': 'absolute_error', 'max_features'...           0.712869
# 14  {'criterion': 'absolute_error', 'max_features'...           0.684423
# 15  {'criterion': 'absolute_error', 'max_features'...           0.653159
# 16  {'criterion': 'absolute_error', 'max_features'...           0.775128
# 17  {'criterion': 'absolute_error', 'max_features'...           0.663368
# 18  {'criterion': 'poisson', 'max_features': None,...           0.741852
# 19  {'criterion': 'poisson', 'max_features': None,...           0.752657
# 20  {'criterion': 'poisson', 'max_features': 'sqrt...           0.712448
# 21  {'criterion': 'poisson', 'max_features': 'sqrt...           0.722795
# 22  {'criterion': 'poisson', 'max_features': 'log2...           0.722082
# 23  {'criterion': 'poisson', 'max_features': 'log2...           0.458119
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.610217           0.733338           0.725459
# 1            0.597246           0.716754           0.767174
# 2            0.561584           0.793367           0.701230
# 3            0.496626           0.638051           0.630493
# 4            0.058680           0.419315           0.702948
# 5            0.518717           0.712831           0.684087
# 6            0.648062           0.725724           0.709671
# 7            0.583038           0.797211           0.710173
# 8            0.619904           0.652692           0.791473
# 9            0.435720           0.711934           0.694698
# 10           0.542123           0.700132           0.614136
# 11           0.587613           0.688477           0.589599
# 12           0.626856           0.725087           0.718528
# 13           0.622994           0.736443           0.724833
# 14           0.685591           0.700756           0.718959
# 15           0.655337           0.668463           0.680459
# 16           0.493782           0.692452           0.708432
# 17           0.545001           0.637199           0.618347
# 18           0.661468           0.758091           0.731553
# 19           0.637618           0.673320           0.694275
# 20           0.600345           0.717692           0.641788
# 21           0.593662           0.576908           0.708275
# 22           0.554703           0.781992           0.716919
# 23           0.552607           0.692738           0.654384
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.666953         0.692336        0.047497                7
# 1            0.716530         0.709887        0.059685                2
# 2            0.619399         0.678614        0.080490               13
# 3            0.605485         0.615013        0.067629               21
# 4            0.706478         0.518897        0.255415               24
# 5            0.624841         0.641554        0.067706               19
# 6            0.679166         0.696705        0.029222                6
# 7            0.706477         0.689656        0.070858                9
# 8            0.695254         0.686849        0.057978               10
# 9            0.474978         0.614823        0.132362               22
# 10           0.675224         0.653568        0.068475               16
# 11           0.681871         0.652937        0.053850               17
# 12           0.742148         0.707875        0.041243                3
# 13           0.654820         0.690392        0.043863                8
# 14           0.632641         0.684474        0.028783               11
# 15           0.709285         0.673341        0.020483               14
# 16           0.693451         0.672649        0.094446               15
# 17           0.687379         0.630259        0.048617               20
# 18           0.695026         0.717598        0.034879                1
# 19           0.762812         0.704136        0.047473                4
# 20           0.744579         0.683370        0.053651               12
# 21           0.616273         0.643583        0.060238               18
# 22           0.743044         0.703748        0.077962                5
# 23           0.679702         0.607510        0.089448               23

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 65
# BMI: 86
# Children: 3
# Sex Male 0 or 1: 1
# Smoker Yes 0 or 1: 0

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
#change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[16085.1275]
# C:\Anaconda 3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %%
import pickle

# %%
#importing the Libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]

# %%
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[['charges']]

# %%
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
import pickle
filename="finalized_model_DRGridsearchCV.sav"

# %%
pickle.dump(grid,open(filename,'wb'))

# %%
loaded_model=pickle.load(open("finalized_model_DRGridsearchCV.sav",'rb'))
preinput=sc.transform([[25,23,0,1,0]])
result=loaded_model.predict(preinput)
# Out:
# C:\Anaconda 3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Anaconda 3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %%
preinput
# Out:
# array([[-1.03327874, -1.24391023, -0.89833872,  1.02378711, -0.50466988]])

# %%
result
# Out:
# array([1694.7964])
